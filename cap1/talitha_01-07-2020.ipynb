# %% [markdown]
# ## Grupo de Estudos Python Fluente - 01/07/2020
# ### Capítulo 1 - Modelo de dados do Python

# %% [markdown]
# #### Referências
#
# --> Documentação Modelos de Dados em Python: https://docs.python.org/pt-br/3/reference/datamodel.html
#
# --> Guia sobre tipos de dados do Real Python: https://realpython.com/python-type-checking/
#
# --> A Beleza do Python por Luciano Ramalho (vídeo): https://www.youtube.com/watch?v=2TLU3d3qgCw
#
# --> SpeckerDeck Luciano Ramalho: https://speakerdeck.com/ramalho?page=1
#
# --> Doctest: https://docs.python.org/3/library/doctest.html
#
# --> Tipos de dados: https://github.com/fluentpython/builtins/blob/master/tipos-de-dados.ipynb
#
# --> Todos os códigos utilizados no livro: https://github.com/fluentpython/example-code

# %%
import this

# %% [markdown]
# Bonito é melhor que feio
# Explícito é melhor que implícito
# Simples é melhor que complexo
# Complexo é melhor que complicado
# Linear é melhor do que aninhado
# Esparso é melhor que denso
# Legibilidade conta
# Casos especiais não são especiais o bastante para quebrar as regras.
# Ainda que praticidade vença a pureza
# Erros nunca devem passar silenciosamente.
# A menos que sejam explicitamente silenciados
# Diante da ambiguidade, recuse a tentação de adivinhar
# Deveria haver um — e preferencialmente apenas um — modo óbvio para fazer algo.
# Embora esse modo possa não ser óbvio a princípio a menos que você seja holandês
# Agora é melhor que nunca
# Embora nunca freqüentemente seja melhor que já
# Se a implementação é difícil de explicar, é uma má ideia
# Se a implementação é fácil de explicar, pode ser uma boa ideia
# Namespaces são uma grande ideia — vamos ter mais dessas!

# %% [markdown]
# ### 1. Modelos de Dados
#
# * **Objeto** é a abstração que o Python usa para se referir a qualquer tipo de **Dado**. Em um programa em Python, todos os dados são representados por **objetos** ou pelo **relacionamento entre objetos**
#
#
# * Todo objeto tem uma **identidade, um tipo e um valor**
#
#
# * A **identidade** de um objeto, nunca muda depois de criado; você pode pensar nisso como endereço de objetos em memória
#
#
# * "Podemos pensar no modelo de dados como uma descrição de Python na forma de um framework. Ele formaliza as interfaces dos blocos de construção da própria linguagem, por exemplo, as sequências, os iteradores, as funções, as classes, os gerenciadores de contexto e assim por diante."
#
#
# * Modelo de Dados == Manual de Instruções

# %% [markdown]
# ### 2. Métodos especiais em Python
#
# ![special_methods.jpg](attachment:special_methods.jpg)
# fonte: https://speakerdeck.com/ramalho/a-beleza-de-python?slide=46
#
# * Os métodos especiais permitem que os seus objetos implementem, tratem e interajam com as construções básicas da linguagem (iterações, coleções, chamadas de funções, etc.)
# * Não precisamos memorizar nomes arbitrários de métodos para realizar operações comuns, provavelmente o Python já criou uma!
# * A utilização de métodos especiais dá acesso a outros métodos e funções nativas da linguagem (como iteração e fatiamento)
#
# * _Exemplo Baralho Pythonico_

# %% [markdown]
# ### 3. Métodos especiais para operadores
#
# ![aritm.jpg](attachment:aritm.jpg)
# fonte: https://speakerdeck.com/ramalho/a-beleza-de-python?slide=55
#
# #### Operadores reversos
#
# ![add_radd.jpg](attachment:add_radd.jpg)
# fonte: https://speakerdeck.com/ramalho/a-beleza-de-python?slide=74

# %%
a = 1
b = 2
c = 3

# %%
a.__add__(b)
# Out:
# 3

# %%
a.__radd__(c)
# Out:
# 4

# %% [markdown]
# ### 4. len()
#
# **Casos especiais não são especiais o bastante para quebrar as regras**
#
# * Obter a quantidade de itens de uma coleção é uma operação comum e precisa funcionar de modo eficiente para tipos básicos e tão diversificados como _str, list, memoryview_ e outros
# * O método `__len__` existe e funciona em coleções definidas pelos usuários

# %% [markdown]
# ### 5. Tipos numéricos quase infinitos
#
# * **int e bool**
# * **float e complex**
# * **byte e bytearray**
# * **decimal**
# * **fraction**

# %%
#fatorial
import math
math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
#bool
bool(0), bool(-313223424)
# Out:
# (False, True)

# %%
#bool também é um inteiro!
int(True), int(False)
# Out:
# (1, 0)

# %%
#float
x = 1.1
x
# Out:
# 1.1

# %%
#fatorial
f'{x:0.20f}'
# Out:
# '1.10000000000000008882'

# %%
#bitearray
ba = bytearray(b)
ba
# Out:
# bytearray(b'\x00\x00')

# %% [markdown]
# ### 6. Representação em string
#
# * Representação em string do objeto para inspeção, com a diferença de que str() é mais sofisticada para exibição aos usuários finais
# * Métodos de string també permitem fatiamento

# %%
animal = "gato"

# %%
animal.__repr__()
# Out:
# "'gato'"

# %%
print(animal.__str__())
# Out:
# gato

# %%
animal[:1]
# Out:
# 'g'
